# %%
# dependencies
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %%
data = pd.read_csv('Alcohol_Consumption_US.csv')
data
# Out:
#         State State_abbrev  Year  Beer (Per capita consumption)  \
# 0     Alabama           AL  2016                           1.09
# 1     Alabama           AL  2015                           1.11
# 2     Alabama           AL  2014                           1.13
# 3     Alabama           AL  2013                           1.14
# 4     Alabama           AL  2012                           1.16
# ...       ...          ...   ...                            ...
# 2035  Wyoming           WY  1981                           1.91
# 2036  Wyoming           WY  1980                           1.85
# 2037  Wyoming           WY  1979                           1.86
# 2038  Wyoming           WY  1978                           1.81
# 2039  Wyoming           WY  1977                           1.78
#
#       Wine (Per capita consumption)  Spirits (Per capita consumption)  \
# 0                              0.26                              0.65
# ...

# %%
lg = sns.lineplot(data=data, x='Year', y='All beverages (Per capita consumption)', hue='State_abbrev', style='State_abbrev')


plt.figure(figsize=(12,8))

# adjusting the size and location of the legend
lg.legend(fontsize=8, bbox_to_anchor= (1.2,1.05))

# setting the title of the chart
lg.set_title('Total Alcohol Consumption of Each State Over Time')
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Total Alcohol Consumption of Each State Over Time')

# %%
sns.barplot(data, x='State_abbrev', y='All beverages (Per capita consumption)')
# Out:
# <Axes: xlabel='State_abbrev', ylabel='All beverages (Per capita consumption)'>
